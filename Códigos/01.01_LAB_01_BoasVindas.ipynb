# %% [markdown]
# ### LAB_01 - Boas vindas. Sejam todos muito bem vindos ao nosso 2ª semestre letivo de 2023.

# %%
print ("Disciplina - Laboratório de Introdução à Programação Estruturada")
print("Palmeiras NÃO tem Mundial")
print("Curintcha se lascou")
print("Vai SP")

# %%
print ('Prof. MS. Gustavo Molina')

# %%
print ('Parabéns sua conta Google está configurada')
