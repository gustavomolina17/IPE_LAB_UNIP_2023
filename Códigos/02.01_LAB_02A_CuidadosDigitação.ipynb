# %% [markdown]
# ### LAB_02A - CUIDADOS NA DIGITAÇÃO DO CÓDIGO

# %% [markdown]
# **1) Letras maiúsculas e minúsculas são diferentes para interpretador.**
#    Assim, **print** e diferente de **Print**.

# %%
print ('meu primeiro comando')
Idade = 120
print (Idade) ##Estou imprimindo em tela
altura= 1.75
## print(Altura)

# %%
print ('meu primeiro comando')

# %% [markdown]
# **2) Aspas são muito importantes e não devem ser esquecidas. Sempre que abrir aspas, não esqueça de fechá-las.**

# %%
print ("meu primeiro comando")

# %%
print ('"meu primeiro comando"')
print ("'meu primeiro comando'")

# %%
print ('meu primeiro comando')

# %% [markdown]
# **3) Parênteses não são opcionais.
# Não remova os parênteses dos comandos e preste a mesma atenção dada às aspas para abri-los e fecha-los.**

# %%
print ('meu primeiro comando')

# %% [markdown]
# **4) Atenção para o indentação.**

# %%
idade = 18
if idade >= 18:
    print ('maior de idade')
else:
    print ('menor de idade')
print ('fim')
