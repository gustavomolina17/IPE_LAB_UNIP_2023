# %% [markdown]
# ### **VARIÁVEIS NUMÉRICAS**

# %% [markdown]
# **1) Operadores Matemáticos.**

# %%
1+2

# %%
3-2

# %%
3*4

# %%
34/7

# %%
34//7

# %%
13%3

# %%
3**3

# %%
float(3)

# %%
int(4.7)

# %%
int(4.3)

# %% [markdown]
# **2) Operadores Relacionais.**

# %%
a = 1
b = 5
c = 2
d = 1

# %%
a == d

# %%
b > a

# %%
a < b

# %%
a == d

# %%
c <= b

# %%
d != d

# %%
d != a

# %%
nota = 5
média = 7
aprovado = nota > média

if aprovado:
  print("parabéns ... você foi aprovado")
else:
  print("foi mal mano ... reprovado")



print(aprovado)

# %%
(a == b) or (a == d)

# %%
(a == b) and (a ==d)

# %% [markdown]
# **3) Operadores de Atribuição.**

# %%
a = 1
a = a + 1
a

# %%
a += 1
a

# %% [markdown]
# **4) Entrada e Conversão de Dados.**

# %%
anos = int(input("Informe o tempo de casa – em nº de anos: "))

valor_por_ano = float(input("Valor por ano: "))

bônus = anos * valor_por_ano

print(f"Bônus de R$ {bônus:.3f}")
